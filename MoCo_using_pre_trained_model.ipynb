# %% [markdown]
# <a href="https://colab.research.google.com/github/marlonq4/simCLR-CSCI4352/blob/main/MoCo_using_pre_trained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd MoCo/
# Out:
# /content/gdrive/My Drive/Git repo/MoCo

# %%
# %cd gdrive/My Drive/Git repo/MoCo
# Out:
# /content/gdrive/My Drive/Git repo/MoCo

# %%
! ls
# Out:
# data  linear.py  model.py  __pycache__	README.md  results  train.py  utils.py

# %%
# !python train.py --batch_size 16 --epochs 100
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Train Epoch: [1/100] Loss: 7.5857: 100% 3125/3125 [03:57<00:00, 13.17it/s]
# Feature extracting: 100% 3125/3125 [00:49<00:00, 63.33it/s]
# Test Epoch: [1/100] Acc@1:22.74% Acc@5:73.16%: 100% 625/625 [00:11<00:00, 53.73it/s]
# Train Epoch: [2/100] Loss: 7.7139: 100% 3125/3125 [03:56<00:00, 13.22it/s]
# Feature extracting: 100% 3125/3125 [00:49<00:00, 63.49it/s]
# ...

# %%
# %cd MoCo/
# Out:
# /content/drive/My Drive/Git repo/MoCo

# %%
# !python linear.py --batch_size 1024 --epochs 100 --model_path 'results/128_4096_0.5_0.999_200_16_100_model.pth'
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Train Epoch: [1/100] Loss: 1.8950 ACC@1: 45.41% ACC@5: 89.00%: 100% 49/49 [00:36<00:00,  1.36it/s]
# Test Epoch: [1/100] Loss: 1.4879 ACC@1: 57.95% ACC@5: 95.00%: 100% 10/10 [00:06<00:00,  1.44it/s]
# Train Epoch: [2/100] Loss: 1.4674 ACC@1: 54.66% ACC@5: 93.84%: 100% 49/49 [00:34<00:00,  1.40it/s]
# Test Epoch: [2/100] Loss: 1.2449 ACC@1: 59.84% ACC@5: 95.59%: 100% 10/10 [00:07<00:00,  1.41it/s]
# ...
